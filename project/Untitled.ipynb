# %%
import recipe

# %%
recipe.main()
# Out:
# === Recipe Manager===
# 1. Add a new recipe to the collection
# 2. Search for recipes by ingredient
# 3. View all recipes
# 4. View a random recipe suggestion
# 5. Exit
# Enter your choice (1-5):  1
# Enter the recipe category(Breakfast, Lunch, Dinner, Dessert) bacha
# Please type Breakfast, Lunch, Dinner or Dessert.
# Enter the recipe category(Breakfast, Lunch, Dinner, Dessert) dinner
# Enter the recipe name bacha
# Enter the ingredients (separated by commas):  meat,salt,pepper,water,bread
# Enter the preperation time in minuts 120
# Enter the cooking instructions cut the bread into small pieces
# Enter the difficulty (Easy, Medium, Hard) medium
# recipies has been updated!
#
# === Recipe Manager===
# 1. Add a new recipe to the collection
# 2. Search for recipes by ingredient
# 3. View all recipes
# 4. View a random recipe suggestion
# 5. Exit
# Enter your choice (1-5):  1
# Enter the recipe category(Breakfast, Lunch, Dinner, Dessert) lunch
# Enter the recipe name mandi
# ...

# %%
recipe.view_all()
# Out:
#   recipe_name  prep_time
# 0    omelette         10

# %%
recipe.search_by_ingredient()
# Out:
# Enter an ingredient:  meat
# Recipes containing 'meat':
#   category recipe_name                                        ingredients  \
# 1   dinner       bacha       ['meat', 'salt', 'pepper', 'water', 'bread']
# 2    lunch       mandi  ['rice', 'chicken/meat', 'salt', 'garlic', 'to...
#
#    prep_time                      instruction Difficulty
# 1        120  cut the bread into small pieces     medium
# 2        120                              NaN       hard
