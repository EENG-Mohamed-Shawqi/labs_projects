# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Classification and KNN with NHL data
#
# _Authors: Joseph Nelson (DC)_
#
# ---
#
# Below you will practice KNN classification on a dataset of NHL statistics.
#
# You will be predicting the `Rank` of a team from predictor variables of your choice.

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import cross_val_score, train_test_split

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
# web location:
local_csv = './data/NHL_Data_GA.csv'

# %% [markdown]
# ### 1. Load the NHL data

# %%
# A:
df_nhl=pd.read_csv('./6.12/data/NHL_Data_GA.csv')

# %% [markdown]
# ### 2. Perform any required data cleaning. Do some EDA.

# %%
# A:
df_nhl.head()
# Out:
#            Team  PTS  Rank         TOI   GF  GA  GF60  GA60   GF%    SF  ...  \
# 0  Washington10  121     1  2001:52:00  115  73  3.45  2.19  61.2  1112  ...
# 1   Vancouver11  117     1  2056:14:00   94  72  2.74  2.10  56.6  1143  ...
# 2    San Jose10  113     1  1929:54:00   90  68  2.80  2.11  57.0  1065  ...
# 3     Chicago10  112     1  2020:23:00  104  83  3.09  2.46  55.6  1186  ...
# 4   Vancouver12  111     1  2052:02:00   86  74  2.51  2.16  53.8  1078  ...
#
#     FF%    CF    CA  CF60  CA60   CF%    Sh%    Sv%   PDO   PIM
# 0  51.3  2138  1935  64.1  58.0  52.5  10.34  93.03  1034  1269
# 1  53.1  2144  1870  62.6  54.6  53.4   8.22  93.16  1014   985
# 2  50.9  1985  1876  61.7  58.3  51.4   8.45  93.46  1019  1195
# 3  58.1  2093  1572  62.2  46.7  57.1   8.77  90.44   992   966
# 4  51.0  2085  1880  61.0  55.0  52.6   7.98  93.36  1013  1049
#
# [5 rows x 28 columns]

# %%
df_nhl.shape
# Out:
# (90, 28)

# %%
df_nhl.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 28 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Team    90 non-null     str
#  1   PTS     90 non-null     int64
#  2   Rank    90 non-null     int64
#  3   TOI     90 non-null     str
#  4   GF      90 non-null     int64
#  5   GA      90 non-null     int64
#  6   GF60    90 non-null     float64
#  7   GA60    90 non-null     float64
#  8   GF%     90 non-null     float64
#  9   SF      90 non-null     int64
#  10  SA      90 non-null     int64
#  11  SF60    90 non-null     float64
#  12  SA60    90 non-null     float64
#  13  SF%     90 non-null     float64
#  14  FF      90 non-null     int64
#  15  FA      90 non-null     int64
#  16  FF60    90 non-null     float64
#  17  FA60    90 non-null     float64
#  18  FF%     90 non-null     float64
#  19  CF      90 non-null     int64
#  20  CA      90 non-null     int64
# ...

# %%
df_nhl.isna().sum()
# Out:
# Team    0
# PTS     0
# Rank    0
# TOI     0
# GF      0
# GA      0
# GF60    0
# GA60    0
# GF%     0
# SF      0
# SA      0
# SF60    0
# SA60    0
# SF%     0
# FF      0
# FA      0
# FF60    0
# FA60    0
# FF%     0
# CF      0
# CA      0
# CF60    0
# CA60    0
# CF%     0
# Sh%     0
# Sv%     0
# PDO     0
# PIM     0
# dtype: int64

# %%
df_nhl.describe()
# Out:
#               PTS       Rank          GF          GA       GF60       GA60  \
# count   90.000000  90.000000   90.000000   90.000000  90.000000  90.000000
# mean    91.977778   2.022222   83.288889   83.288889   2.442222   2.444000
# std     12.524114   0.820767   10.376339    9.694484   0.325331   0.313522
# min     62.000000   1.000000   57.000000   64.000000   1.700000   1.730000
# 25%     82.250000   1.000000   76.000000   75.500000   2.232500   2.202500
# 50%     92.500000   2.000000   84.000000   84.000000   2.400000   2.495000
# 75%    102.000000   3.000000   90.000000   89.000000   2.600000   2.670000
# max    121.000000   3.000000  115.000000  107.000000   3.450000   3.240000
#
#              GF%           SF           SA       SF60  ...        FF%  \
# count  90.000000    90.000000    90.000000  90.000000  ...  90.000000
# mean   49.981111  1068.333333  1068.333333  31.252222  ...  49.966667
# std     4.644554    95.929047    75.514118   2.237637  ...   2.797913
# ...

# %%
df_nhl.select_dtypes(include='number').skew()
# Out:
# PTS    -0.217053
# Rank   -0.041525
# GF      0.102992
# GA      0.089353
# GF60    0.399036
# GA60   -0.007275
# GF%    -0.097054
# SF     -0.293246
# SA     -0.450466
# SF60   -0.173997
# SA60   -0.428445
# SF%     0.089305
# FF     -0.264911
# FA     -0.369155
# FF60   -0.209436
# FA60   -0.245451
# FF%     0.009990
# CF     -0.248907
# CA     -0.170827
# CF60   -0.280665
# CA60   -0.143956
# CF%    -0.127774
# Sh%     0.345508
# Sv%    -0.249169
# PDO     0.320748
# PIM     0.534980
# dtype: float64

# %% [markdown]
# ### 3. Set up the `Rank` variable as your target. How many classes are there?

# %%
# A:
df_nhl['Rank'].value_counts()
# Out:
# Rank
# 3    31
# 2    30
# 1    29
# Name: count, dtype: int64

# %%
y=df_nhl['Rank']

# %% [markdown]
# ### 4. What is the baseline accuracy?

# %%
# A: most frequent class / total samples
print(f"Baseline accuracy is :{y.value_counts().max()/len(y):.3f}")
# Out:
# Baseline accuracy is :0.344

# %% [markdown]
# ### 5. Choose 4 features to be your predictor variables and set up your design matrix.

# %%
# A:
features=df_nhl.select_dtypes(include='number').drop(columns='Rank').columns.copy()
X=df_nhl[features]

# %% [markdown]
# ### 6. Fit a `KNeighborsClassifier` with 1 neighbor using the target and predictors.

# %%
# A:
knn=KNeighborsClassifier(n_neighbors=1)

# %% [markdown]
# ### 7. Evaluate the accuracy of your model.
# - Is it better than baseline?
# - Is it legitimate?

# %%
# A:
cross_val_score(knn,X,y,cv=5).mean()
# Out:
# np.float64(0.5)

# %% [markdown]
# **No, the base line worse than the excpected accuracy to the KNN model**

# %% [markdown]
# ### 8. Create a 50-50 train-test-split of your target and predictors. Refit the KNN and assess the accuracy.

# %%
# A:
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.5,random_state=42)

# %% [markdown]
# ### 9. Evaluate the test accuracy of a KNN where K == number of rows in the training data.

# %%
# A:
knn= KNeighborsClassifier(n_neighbors=len(X_train))
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=45)

# %%
knn.score(X_test,y_test)
# Out:
# 0.3111111111111111

# %% [markdown]
# **As it appears that the accuarcy is lower than the baseline prediction due the neighbour number is very high,\
# where it can produce biased resaults.**

# %% [markdown]
# ### 10. Fit the KNN at values of K from 1 to the number of rows in the training data.
# - Store the test accuracy in a list.
# - Plot the test accuracy vs. the number of neighbors.

# %%
# A:
score_list=[]
for i in range(1,len(X_train)):
    knn= KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train,y_train)
    score=knn.score(X_test,y_test)
    score_list.append({'k':i,
                      'accuracy':round(score,3)})

# %%
score_list= pd.DataFrame(score_list)

plt.figure(figsize=(8, 5))
sns.lineplot(data=score_list, x='k', y='accuracy', marker='o', color='crimson')

plt.title('KNN Accuracy Profile')
plt.grid(True)

# %% [markdown]
# ### 11. Fit KNN across different values of K and plot the mean cross-validated accuracy with 5 folds.

# %%
# A:
cv_score=[]
for i in range(1,36):
    knn_test=KNeighborsClassifier(n_neighbors=i)
    scores=cross_val_score(knn_test,X_train,y_train,cv=5).mean()
    cv_score.append({'k':i,
                     'accuracy':scores})

cv_score=pd.DataFrame(cv_score)

# %%
plt.figure(figsize=(8, 5))
sns.lineplot(data=cv_score, x='k', y='accuracy', marker='o', color='crimson')

plt.title('KNN Accuracy Profile')
plt.grid(True)

# %% [markdown]
# ### 12. Standardize the predictor matrix and cross-validate across the different K.
# - Plot the standardized mean cross-validated accuracy against the unstandardized. Which is better?
# - Why?

# %%
# A:
ss=StandardScaler()
Xs_train=ss.fit_transform(X_train)
Xs_test=ss.transform(X_test)

# %%
s_cv_score=[]
for i in range(1,36):
    s_knn_test=KNeighborsClassifier(n_neighbors=i)
    s_scores=cross_val_score(s_knn_test,Xs_train,y_train,cv=5).mean()
    s_cv_score.append({'k':i,
                     'accuracy':scores})

s_cv_score=pd.DataFrame(s_cv_score)

# %%
plt.figure(figsize=(8, 5))
sns.lineplot(data=s_cv_score, x='k', y='accuracy', marker='o', color='crimson')

plt.title('KNN Accuracy Profile')
plt.grid(True)

# %% [markdown]
# ## What was the best 'k'?
#
# Using `GridSearch` & `Pipeline` find the best `k` for the KNN model
